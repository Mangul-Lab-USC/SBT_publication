# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as tkr
import numpy as np
import statsmodels.api as sm
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import warnings
warnings.simplefilter('ignore')
from lifelines import KaplanMeierFitter

# %% [markdown]
# ## Reading csv files

# %%
reads = pd.read_csv('../summary_data/summary_tcga_reads.csv')
vj = pd.read_csv('../summary_data/summary_tcga_VJ.csv')
cdr3 = pd.read_csv('../summary_data/summary_tcga_cdr3.csv')
microbiome = pd.read_csv('../summary_data/summary_tcga_microbiome.csv')
mtDNA = pd.read_csv('../summary_data/summary_tcga_mtDNA.csv')
purity = pd.read_csv('../summary_data/purity.csv')
purity = purity.dropna(subset=['CPE'])
tcga_cdr = pd.read_csv('../summary_data/TCGA-CDR.csv')

# %% [markdown]
# ## Joining data into single dataframe

# %%
sbt = cdr3.merge(vj, left_on='sample', right_on='sample', suffixes=('', 'vj'))
sbt = sbt.merge(microbiome, left_on='sample', right_on='sample', suffixes=(False, False))
sbt = sbt.merge(mtDNA, left_on='sample', right_on='sample', suffixes=(False, False))
sbt = sbt.merge(reads, left_on='sample', right_on='sample', suffixes=(False, False))
sbt['FileID'] = sbt['sample'].str[:36]


metadata = pd.read_csv('../summary_data/explore_case_table.tsv', delimiter="\t")
metadata = metadata.merge(pd.read_csv('../summary_data/gdc_sample_sheet.tsv', delimiter="\t"), left_on='Case ID', right_on='Case ID', suffixes=(False, False))
metadata['FileID'] = metadata['File Name'].str[:36]
metadata = metadata[['FileID', 'Case ID', 'Sample ID']]


data = metadata.merge(sbt, left_on='FileID', right_on='FileID', suffixes=(False, False))
data = data.merge(tcga_cdr, left_on='Case ID', right_on='bcr_patient_barcode', suffixes=(False, False))
data_with_purity = data.merge(purity, left_on='Sample ID', right_on='Sample ID', suffixes=(False, False))

data_with_purity['Age'] = data_with_purity['age_at_initial_pathologic_diagnosis']
sbt = sbt.drop(columns=['n_unique_pe'])
sbt = sbt.drop(columns=['name'])
sbt = sbt.drop(columns=['mtDNA_ID'])
sbt = sbt.drop(columns=['FileID'])
data_with_purity['Sex'] = data_with_purity['gender'] == "FEMALE"
data_with_purity = data_with_purity.dropna(subset=['Age'])

# %% [markdown]
# ## Average of female samples

# %%
np.mean(data_with_purity['Sex'])
# Out:
# 0.5384615384615384

# %% [markdown]
# ## Linear model for SBT features

# %%
X = data_with_purity[['Sex', 'Age','n_unique_pe','CPE']]
X['Sex'] = X['Sex'].astype(int)

X = np.array(X)
X = sm.add_constant(X)

pvalues = []
for i in range(1,len(sbt.columns)):
    y = data_with_purity[sbt.columns[i]]
    y = np.array(y)
    mod = sm.OLS(y,X)
    fii = mod.fit()
    p_values = fii.summary2().tables[1]['P>|t|']
    pvalues.append([sbt.columns[i],p_values[1:]['x1'],p_values[1:]['x2'],p_values[1:]['x3'],p_values[1:]['x4']])

pvalues = pd.DataFrame(pvalues)   
pvalues.columns = ['feature','gender','age','#reads','purity']
pvalues.round(4)
# Out:
#           feature  gender     age  #reads  purity
# 0            nIGH  0.9378  0.8402  0.0000  0.0000
# 1            nIGK  0.1697  0.7334  0.0000  0.0000
# 2            nIGL  0.5738  0.9426  0.0000  0.0000
# 3           nTCRA  0.2951  0.1238  0.0000  0.0000
# 4           nTCRB  0.4097  0.1563  0.0000  0.0000
# 5           nTCRD  0.2372  0.5499  0.0000  0.0000
# 6           nTCRG  0.5731  0.2843  0.0000  0.0000
# 7         loadIGH  0.1469  0.5531  0.0014  0.0000
# 8         loadIGK  0.2641  0.9419  0.0000  0.0000
# 9         loadIGL  0.1680  0.9750  0.0001  0.0000
# 10       loadTCRA  0.7902  0.2191  0.0000  0.2574
# 11       loadTCRB  0.2634  0.1576  0.0000  0.0000
# 12       loadTCRD  0.4214  0.1687  0.0286  0.0000
# 13       loadTCRG  0.8267  0.3097  0.0002  0.0000
# 14       alphaIGH  0.9145  0.7512  0.0009  0.0000
# 15       alphaIGK  0.0827  0.1113  0.0247  0.0001
# 16       alphaIGL  0.5204  0.1434  0.0128  0.0000
# 17      alphaTCRA  0.2749  0.4590  0.0000  0.0000
# 18      alphaTCRB  0.0854  0.0039  0.0000  0.0000
# 19      alphaTCRD  0.2020  0.2220  0.0000  0.0000
# 20      alphaTCRG  0.6482  0.8058  0.0035  0.0000
# 21         nIGHvj  0.3783  0.8649  0.0001  0.0000
# 22         nIGKvj  0.3130  0.7681  0.0001  0.0000
# 23         nIGLvj  0.4926  0.8463  0.0000  0.0000
# 24        nTCRAvj  0.7441  0.4158  0.0000  0.0000
# 25        nTCRBvj  0.5235  0.0137  0.0244  0.0001
# 26        nTCRDvj  0.1406  0.6169  0.0031  0.0000
# 27        nTCRGvj  0.9991  0.4041  0.2039  0.0572
# 28      loadIGHvj  0.2912  0.4445  0.0178  0.3205
# 29      loadIGKvj  0.3925  0.7225  0.1244  0.0012
# 30      loadIGLvj  0.1754  0.1514  0.0342  0.0000
# 31     loadTCRAvj  0.3232  0.1811  0.0000  0.0000
# 32     loadTCRBvj  0.3374  0.8231  0.0247  0.6059
# 33     loadTCRDvj  0.5866  0.0466  0.3022  0.0046
# 34     loadTCRGvj  0.6407  0.3364  0.1460  0.0557
# 35     alphaIGHvj  0.2003  0.8335  0.0003  0.0000
# 36     alphaIGKvj  0.3529  0.6596  0.0032  0.0000
# 37     alphaIGLvj  0.4533  0.6217  0.0000  0.0000
# 38    alphaTCRAvj  0.2523  0.6287  0.1006  0.0001
# 39    alphaTCRBvj  0.2101  0.0216  0.0331  0.0003
# 40    alphaTCRDvj  0.4967  0.9068  0.1763  0.0000
# 41    alphaTCRGvj     NaN     NaN     NaN     NaN
# 42        n_viral  0.7259  0.0001  0.0000  0.1289
# 43        n_fungi  0.5196  0.0358  0.0000  0.0524
# 44     n_protozoa  0.5034  0.0751  0.0000  0.0342
# 45   n_microbiome  0.8964  0.0015  0.0000  0.0629
# 46         dosage  0.7706  0.0413  0.0000  0.0418
# 47  n_unm_both_pe  0.9769  0.0007  0.0000  0.0180
# 48      n_unm1_pe  0.6460  0.3376  0.0000  0.0000
# 49      n_unm2_pe  0.3972  0.6432  0.0000  0.8066

# %% [markdown]
# # Variables for Survival Analysis

# %%
from lifelines import CoxPHFitter
import matplotlib as mpl
from lifelines.statistics import logrank_test

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False


time_ = 'OS.time'
event_ = 'OS'
feature = 'alphaTCRG'

# %% [markdown]
# # Kaplan Meyer fit with p-value from Logrank test

# %%
#Selecting features of interest
data_ = data_with_purity[[time_, event_, feature]]

#Dividing into two groups for Kaplan-Meyer plot
df0 = data_.loc[data_[feature] == 0] 
df1 = data_.loc[data_[feature] > 0] 

#Log-Rannk test
print("Log-Rank test")
results = logrank_test(df0[time_], df1[time_], event_observed_A=df0[event_], event_observed_B=df1[event_])
results.print_summary()
print("\n\n")



#Cox regression
print("Cox Regression")
cph = CoxPHFitter()
cph.fit(data_, duration_col=time_, event_col=event_)
cph.print_summary()
print("\n\n")


#Kaplan Meyer plot
print("Kaplan-Meyer plot")
fig, ax = plt.subplots(figsize=(9, 6))

kmf = KaplanMeierFitter()
kmf.fit( df0[time_],df0[event_], label=feature+" = 0")
kmf.plot(ci_show=False)
kmf.fit( df1[time_],df1[event_], label=feature+" > 0")
kmf.plot(ci_show=False)

plt.legend(bbox_to_anchor=(0,.92,1,0.2), loc="upper left", prop={'size': 13},  ncol=3)
ax.tick_params(axis='both', which='major', labelsize=12)

plt.ylabel('Survival probability', fontsize=15)
plt.xlabel('Time', fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# Log-Rank test
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>t_0</th>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>null_distribution</th>
#       <td>chi squared</td>
#     </tr>
#     <tr>
#       <th>degrees_of_freedom</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>test_name</th>
#       <td>logrank_test</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>test_statistic</th>
#       <th>p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.56</td>
#       <td>0.45</td>
#     </tr>
#   </tbody>
# </table>
# Cox Regression
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>model</th>
#       <td>lifelines.CoxPHFitter</td>
#     </tr>
#     <tr>
#       <th>duration col</th>
#       <td>'OS.time'</td>
#     </tr>
#     <tr>
#       <th>event col</th>
#       <td>'OS'</td>
#     </tr>
#     <tr>
#       <th>baseline estimation</th>
#       <td>breslow</td>
#     </tr>
#     <tr>
#       <th>number of observations</th>
#       <td>507</td>
#     </tr>
#     <tr>
#       <th>number of events observed</th>
#       <td>183</td>
#     </tr>
#     <tr>
#       <th>partial log-likelihood</th>
#       <td>-976.22</td>
#     </tr>
#     <tr>
#       <th>time fit was run</th>
#       <td>2020-05-12 22:39:10 UTC</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>coef</th>
#       <th>exp(coef)</th>
#       <th>se(coef)</th>
#       <th>coef lower 95%</th>
#       <th>coef upper 95%</th>
#       <th>exp(coef) lower 95%</th>
#       <th>exp(coef) upper 95%</th>
#       <th>z</th>
#       <th>p</th>
#       <th>-log2(p)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alphaTCRG</th>
#       <td>-0.28</td>
#       <td>0.76</td>
#       <td>0.38</td>
#       <td>-1.02</td>
#       <td>0.47</td>
#       <td>0.36</td>
#       <td>1.60</td>
#       <td>-0.73</td>
#       <td>0.47</td>
#       <td>1.10</td>
#     </tr>
#   </tbody>
# </table><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>Concordance</th>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>Log-likelihood ratio test</th>
#       <td>0.57 on 1 df</td>
#     </tr>
#     <tr>
#       <th>-log2(p) of ll-ratio test</th>
#       <td>1.15</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# Kaplan-Meyer plot

# %% [markdown]
# # Considering only 20% top/bottom alphaTCRG values

# %%
# Selecting features of interest and sorting based on alphaTCRG value
temp = data_with_purity[[time_, event_, feature]]
temp = temp.sort_values(feature)

# Selecting only 20% top/bottom
data_ = temp.head(100)
data_ = pd.concat([data_, temp.tail(100)])

# Diving into two groups for the Kaplan-Meyer plot
df0 = data_.loc[data_[feature] == 0] 
df1 = data_.loc[data_[feature] > 0] 



#Log-Rannk test
print("Log-Rank test")
results = logrank_test(df0[time_], df1[time_], event_observed_A=df0[event_], event_observed_B=df1[event_])
results.print_summary()
print("\n\n")


#Cox regression
print("Cox Regression")
cph = CoxPHFitter()
cph.fit(data_, duration_col=time_, event_col=event_)
cph.print_summary()
print("\n\n")


#Kaplan Meyer plot
print("Kaplan-Meyer plot")
fig, ax = plt.subplots(figsize=(9, 6))

kmf = KaplanMeierFitter()
kmf.fit( df0[time_],df0[event_], label=feature+" = 0")
kmf.plot(ci_show=False)
kmf.fit( df1[time_],df1[event_], label=feature+" > 0")
kmf.plot(ci_show=False)

plt.legend(bbox_to_anchor=(0,.92,1,0.2), loc="upper left", prop={'size': 13},  ncol=3)
ax.tick_params(axis='both', which='major', labelsize=12)

plt.ylabel('Survival probability', fontsize=15)
plt.xlabel('Time', fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# Log-Rank test
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>t_0</th>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>null_distribution</th>
#       <td>chi squared</td>
#     </tr>
#     <tr>
#       <th>degrees_of_freedom</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>test_name</th>
#       <td>logrank_test</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>test_statistic</th>
#       <th>p</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.70</td>
#       <td>0.40</td>
#     </tr>
#   </tbody>
# </table>
# Cox Regression
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>model</th>
#       <td>lifelines.CoxPHFitter</td>
#     </tr>
#     <tr>
#       <th>duration col</th>
#       <td>'OS.time'</td>
#     </tr>
#     <tr>
#       <th>event col</th>
#       <td>'OS'</td>
#     </tr>
#     <tr>
#       <th>baseline estimation</th>
#       <td>breslow</td>
#     </tr>
#     <tr>
#       <th>number of observations</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>number of events observed</th>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>partial log-likelihood</th>
#       <td>-327.67</td>
#     </tr>
#     <tr>
#       <th>time fit was run</th>
#       <td>2020-05-12 22:39:11 UTC</td>
#     </tr>
#   </tbody>
# </table>
# </div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>coef</th>
#       <th>exp(coef)</th>
#       <th>se(coef)</th>
#       <th>coef lower 95%</th>
#       <th>coef upper 95%</th>
#       <th>exp(coef) lower 95%</th>
#       <th>exp(coef) upper 95%</th>
#       <th>z</th>
#       <th>p</th>
#       <th>-log2(p)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>alphaTCRG</th>
#       <td>-0.33</td>
#       <td>0.72</td>
#       <td>0.40</td>
#       <td>-1.11</td>
#       <td>0.45</td>
#       <td>0.33</td>
#       <td>1.56</td>
#       <td>-0.83</td>
#       <td>0.40</td>
#       <td>1.31</td>
#     </tr>
#   </tbody>
# </table><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <th>Concordance</th>
#       <td>0.52</td>
#     </tr>
#     <tr>
#       <th>Log-likelihood ratio test</th>
#       <td>0.75 on 1 df</td>
#     </tr>
#     <tr>
#       <th>-log2(p) of ll-ratio test</th>
#       <td>1.38</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# Kaplan-Meyer plot
